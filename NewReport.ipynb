# %% [markdown]
# # OpenStreetMap Data Case Study

# %% [markdown]
# ## Map Area
#
# San Jose, CA, United States
#
# * (https://mapzen.com/data/metro-extracts/metro/san-jose_california/)
#
# This map is close to my home town and I am interested in knowing all the interesting facts that I can find with my queries.

# %%
from IPython.display import Image
Image(filename="Capture.png")

# %% [markdown]
# ## Problems Encountered in the Map
#
# After initially downloading and uncompressing the file, I made a small sample file of size 29 MB. I used the data.py python code to run this sample file. I noticed the following problems with the data.
#
# * Abbreviated street names ("N. Mathilda Ave","Wolfe Rd.")
# * Inconsistent city names ("SUnnyvale","San José","San Jose")
# * Inconsistent postal codes ("CA 95054","95014-2225", "95014")
# * Inconsistent phone numbers("1 408 732 4222","1.408.245.5620","+1-800-POLYCOM")

# %% [markdown]
# ## Abbreviated Street Names
#
# I was able to find most of the inconsistencies in the street names of the sample.osm file using print statements in data.py. To clean the abbreviated street names I used dictionaries for look-ups. Here is the snippet of the code used to clean the street names and the resulting fixed names.

# %%
def update_addr_name(name, mapping):
    newname = ''
    #replace N with North,S with South etc.
    if name.split()[0] in direction_addr:
        for key,val in direction.iteritems():
            name = name.replace(key,val)
    if name in expand_addr:
        newname = expand_addr[name]
        print name,' ----> ',newname
        return (newname)
    #replace 1st with 'First' etc.
    name_list = name.split()
    for items in name_list:
        if items in street_num:
            for key,val in street_num.iteritems():
                name = name.replace(key,val)
        
    last_word = name.split()[-1]
    if last_word in mapping_addr:
        #get the words except the last one
        for n in range(len(name.split())-1):
            newname += name.split()[n]
            newname +=' '
        newname += mapping_addr[last_word]
        print name,' ----> ',newname
        return newname
    else:
        return name

# %% [markdown]
#     Hollenbeck Ave  ---->  Hollenbeck Avenue
#     Meridian Ave  ---->  Meridian Avenue
#     Santa Teresa Blvd  ---->  Santa Teresa Boulevard
#     Monterey Hwy  ---->  Monterey Highway
#     Minto Dr  ---->  Minto Drive
#     Cherry Ave  ---->  Cherry Avenue
#     Los Gatos Blvd  ---->  Los Gatos Boulevard
#     Walsh Ave  ---->  Walsh Avenue
#     Meridian Ave  ---->  Meridian Avenue
#     North McCarthy Blvd  ---->  North McCarthy Boulevard
#     Foxworthy Ave  ---->  Foxworthy Avenue
#     Saratoga Los Gatos Rd  ---->  Saratoga Los Gatos Road
#     Saratoga Los Gatos Rd  ---->  Saratoga Los Gatos Road
#     Perivale Ct  ---->  Perivale Court
#     Monroe St  ---->  Monroe Street
#     Wolfe Rd  ---->  Wolfe Road
#     East Duane Ave  ---->  East Duane Avenue
#     West Westashington Ave  ---->  West Westashington Avenue
#     Silver Creek Valley Rd  ---->  Silver Creek Valley Road
#     Samaritan Dr  ---->  Samaritan Drive
#     Monterey Hwy  ---->  Monterey Highway
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Westfield Ave  ---->  Westfield Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Greenbriar Ave  ---->  Greenbriar Avenue
#     Branham Ln  ---->  Branham Lane
#     Berryessa Rd  ---->  Berryessa Road
#     Los Gatos Blvd  ---->  Los Gatos Boulevard
#     Los Gatos Blvd  ---->  Los Gatos Boulevard
#     Meridian Ave  ---->  Meridian Avenue
#     Berryessa Rd  ---->  Berryessa Road
#     Quimby Rd  ---->  Quimby Road
#     Stevens Creek Blvd  ---->  Stevens Creek Boulevard
#     Vista Montaña  ---->  Vista Montana
#     1425 E Dunne Ave  ---->  1425 E Dunne Avenue
#     Fountain Oaks Dr  ---->  Fountain Oaks Drive
#     Homestead Rd  ---->  Homestead Road
#     Blake Ave  ---->  Blake Avenue
#     Gaundabert Ln  ---->  Gaundabert Lane
#     North Blaney Ave  ---->  North Blaney Avenue
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Mt. Hamilton Rd  ---->  Mt. Hamilton Road
#     San Antonio Valley Rd  ---->  San Antonio Valley Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     San Antonio Valley Rd  ---->  San Antonio Valley Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Samaritan Dr  ---->  Samaritan Drive
#     Samaritan Dr  ---->  Samaritan Drive
#     Samaritan Dr  ---->  Samaritan Drive
#     Samaritan Dr  ---->  Samaritan Drive
#     Cabrillo Ave  ---->  Cabrillo Avenue
#     Mission College Blvd  ---->  Mission College Boulevard
#     Seaboard Ave  ---->  Seaboard Avenue
#     McCarthy Blvd  ---->  McCarthy Boulevard
#     Stevens Creek Blvd  ---->  Stevens Creek Boulevard
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Los Gatos Blvd  ---->  Los Gatos Boulevard
#     Los Gatos Blvd  ---->  Los Gatos Boulevard
#     Los Gatos Blvd  ---->  Los Gatos Boulevard
#     Los Gatos Blvd  ---->  Los Gatos Boulevard
#     Los Gatos Blvd  ---->  Los Gatos Boulevard
#     Saratoga Ave  ---->  Saratoga Avenue
#     Linwood Dr  ---->  Linwood Drive
#     The Alameda Ave  ---->  The Alameda Avenue
#     North McCarthy Blvd  ---->  North McCarthy Boulevard
#     Palm Valley Blvd  ---->  Palm Valley Boulevard
#     Palm Valley Blvd  ---->  Palm Valley Boulevard
#     Palm Valley Blvd  ---->  Palm Valley Boulevard
#     Palm Valley Blvd  ---->  Palm Valley Boulevard
#     Casa Verde St  ---->  Casa Verde Street
#     Monroe St  ---->  Monroe Street
#     Palm Valley Blvd  ---->  Palm Valley Boulevard
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     Mt Hamilton Rd  ---->  Mount Hamilton Road
#     West Maude Ave  ---->  West Maude Avenue
#     Samaritan Dr  ---->  Samaritan Drive
#     Los Gatos Blvd  ---->  Los Gatos Boulevard
#     Hillsdale Ave  ---->  Hillsdale Avenue
#     Vista Montaña  ---->  Vista Montana

# %% [markdown]
# ## Inconsistent City Names
#
# To clean the city names I used dictionary 'mapping_city'  for look-ups to match city names with accent on letters, lower case etc. Here is the snippet of the code with a part of its output.

# %%
def update_city_name(name,mapping):
    new_name=''
    if name in mapping_city: 
        new_name = mapping_city[name]
        print name,' ----> ',repr(new_name)
        return repr(new_name)
    else:
        return repr(name)

# %% [markdown]
#     San José  ---->  'San Jose'
#     san jose  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     san jose  ---->  'San Jose'
#     Los Gatos, CA  ---->  'Los Gatos'
#     San José  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     san jose  ---->  'San Jose'
#     san Jose  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     san Jose  ---->  'San Jose'
#     sunnyvale  ---->  'Sunnyvale'
#     sunnyvale  ---->  'Sunnyvale'
#     San José  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     SUnnyvale  ---->  'Sunnyvale'
#     cupertino  ---->  'Cupertino'
#     San José  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     San José  ---->  'San Jose'
#     Los Gato  ---->  'Los Gatos'

# %% [markdown]
# ## Inconsistent Postcodes
#
# Some of the postcodes had 9-digits, some had 5-digits and some had the state name in them. To clean up I used regex (POSTCODE = re.compile(r'[9][0-9]{4}$') to match the 5-digit postcode and changed the remaining postcodes to 5-digits to be consistent. The state name was stripped from the postcode and only the postcode was retained. Here is a snippet of the code and a part of its output.

# %%
def update_postcode(postcode):
    if POSTCODE.match(postcode):
        return postcode
    elif postcode.split()[0] == 'CA':
        print postcode,' ---->',postcode.split()[1]
        return (postcode.split()[1])
    else:
        print postcode,' ----> ',postcode.split('-')[0]
        return (postcode.split('-')[0])

# %% [markdown]
#     95014-2029  ---->  95014
#     95014-2405  ---->  95014
#     95037-3635  ---->  95037
#     95037-4530  ---->  95037
#     95014-2456  ---->  95014
#     95014-2130  ---->  95014
#     95037-9221  ---->  95037
#     95014-2225  ---->  95014
#     CA 95054  ----> 95054
#     95014-2225  ---->  95014
#     95014-2522  ---->  95014
#     95014-2522  ---->  95014
#     95014-2522  ---->  95014
#     95014-2522  ---->  95014
#     95014-2522  ---->  95014
#     CA 95110  ----> 95110
#     95014-2456  ---->  95014
#     95014-2456  ---->  95014
#     95014-2465  ---->  95014

# %% [markdown]
# ## Inconsistent Phone Numbers
#
# The phone numbers were in many different formats and they were made into a standard format: (xxx) xxx-xxxx  I used a regex function PHONENUM =re.compile(r'[4,5,6,8][0-9]{2}-[0-9]{3}-[0-9]{4}$') to get all the phone numbers which were in standard form. The rest of the phone numbers were parsed with extra +1,'.' etc removed and made into standard form.
# Here is a snippet of the code and its output. There were two wrong phone numbers - one with just '+1' and the second with just 7 digits. Both were tagged 'Invalid phone number'.

# %%
def update_phone(phonenum):
    if PHONENUM.match(phonenum):
        return phonenum
    else:
        new_num=''
        count = 0
        for i in range(len(phonenum)):
        #get the first number
            if (phonenum[i] in ['4','5','6','8']) and count == 0:
                new_num += "("
                new_num += phonenum[i]
                count +=1
            elif (count > 0) and (count <= 12):
                if phonenum[i].isalnum():
                    new_num += phonenum[i]
                    count +=1
                    if count == 3:
                        new_num+= ") "
                    if count == 6:
                        if new_num[6].isdigit():
                            new_num += "-"
    if len(new_num) > 9 and len(new_num) <=14:
        print phonenum,' ----> ',new_num
        return new_num    
    else:
        print 'Invalid phone number: ',phonenum
        return ('Invalid phone number')

# %% [markdown]
#     +1 408 736 6859  ---->  (408) 736-6859
#     4087382177  ---->  (408) 738-2177
#     +1 408 733 1304  ---->  (408) 733-1304
#     +1 408 789 0037  ---->  (408) 789-0037
#     8882624386  ---->  (888) 262-4386
#     4086549000  ---->  (408) 654-9000
#     4084869727  ---->  (408) 486-9727
#     4084533133  ---->  (408) 453-3133
#     4089889100  ---->  (408) 988-9100
#     (408) 277-4625  ---->  (408) 277-4625
#     +1-408-298-9731  ---->  (408) 298-9731
#     +1.408.559.6900  ---->  (408) 559-6900
#     +1 408-778-0551  ---->  (408) 778-0551
#     4088718765  ---->  (408) 871-8765
#     4084507990  ---->  (408) 450-7990
#     4087271419  ---->  (408) 727-1419
#     +1 (408) 364-3700  ---->  (408) 364-3700
#     +1 408 739 7717  ---->  (408) 739-7717
#     (408) 730-5510  ---->  (408) 730-5510
#     + 408 980 6400  ---->  (408) 980-6400
#     +1 408 452 1060  ---->  (408) 452-1060
#     +1 408 774 1889  ---->  (408) 774-1889
#     +1 408 294 2558  ---->  (408) 294-2558
#     +1-408-423-8502  ---->  (408) 423-8502
#     1 408 732 4222  ---->  (408) 732-4222
#     4087208538  ---->  (408) 720-8538
#     4088300094  ---->  (408) 830-0094
#     4082436868  ---->  (408) 243-6868
#     4087398960  ---->  (408) 739-8960
#     4087067979  ---->  (408) 706-7979
#     +1 408 245 2253  ---->  (408) 245-2253
#     +1 408 245 9500  ---->  (408) 245-9500
#     Invalid phone number:  2924779
#     4082861412  ---->  (408) 286-1412
#     +1-408-975-9371  ---->  (408) 975-9371
#     +14082635526  ---->  (408) 263-5526
#     +1 408-293-8810  ---->  (408) 293-8810
#     +1 408 378 0622  ---->  (408) 378-0622
#     +1-408-263-6788  ---->  (408) 263-6788
#     +1 408 246 1484  ---->  (408) 246-1484
#     +14082719504  ---->  (408) 271-9504
#     Invalid phone number:  +1

# %% [markdown]
# ## Data Overview
#
# The file sizes are:
#
#     * san-jose_california.osm------------- 295 MB
#     * sanjose.db-------------------------- 165 MB
#     * nodes.csv--------------------------- 113 MB
#     * nodes_tags.csv---------------------- 2.7 MB
#     * ways.csv----------------------------  10 MB
#     * ways_tags.csv-----------------------  22 MB
#     * ways_nodes.csv----------------------  38 MB

# %% [markdown]
# ### Number of nodes

# %%
sqlite> SELECT count(*) FROM nodes;

# %% [markdown]
# 1337915

# %% [markdown]
# ### Number of Ways

# %%
sqlite> SELECT count(*) FROM ways;

# %% [markdown]
# 177549

# %% [markdown]
# ### Number of Unique Users

# %%
sqlite> SELECT count(DISTINCT(users.uid)) FROM
   ...> (SELECT uid FROM nodes UNION ALL SELECT uid FROM ways) users;

# %% [markdown]
# 1323

# %% [markdown]
# ### Top 10 Contributors

# %%
sqlite> SELECT users.user, count(*) as num FROM
   ...> (SELECT user FROM nodes UNION ALL SELECT user FROM ways) users
   ...> GROUP BY users.user
   ...> ORDER BY num DESC
   ...> LIMIT 15;

# %% [markdown]
#     nmixter      288079
#     mk408        151377
#     Bike Mapper  81330
#     samely       77912
#     dannykath    72315
#     RichRico     71846
#     karitotp     57291
#     n76          38018
#     Minh Nguyen  35071
#     MustangBuyer 34076
#     matthieun    32702
#     calfarome    31620
#     doug_sfba    30221
#     beddy        28475
#     Luis36995    22559

# %% [markdown]
# ### Number of users having 1 post

# %%
sqlite> SELECT COUNT(*) FROM
   ...> (SELECT users.user,COUNT(*) as num
   ...> FROM (SELECT user FROM nodes UNION ALL SELECT user FROM ways) users
   ...> GROUP BY users.user
   ...> HAVING num=1);

# %% [markdown]
# 291

# %% [markdown]
# ### Additional Data Exploration

# %% [markdown]
# ### Top 10 Cuisines

# %%
sqlite> SELECT value,count(*) as cnt FROM nodes_tags
   ...> WHERE key == 'cuisine'
   ...> GROUP BY value
   ...> ORDER BY cnt DESC
   ...> LIMIT 10;

# %% [markdown]
#     vietnamese   94
#     mexican      89
#     sandwich     88
#     pizza        79
#     chinese      76
#     coffee_shop  55
#     japanese     43
#     burger       42
#     indian       38
#     american     32

# %% [markdown]
# ### Top 10 Leisure Amenities

# %%
sqlite> SELECT value, count(*) as cnt FROM nodes_tags
   ...> WHERE key == 'leisure'
   ...> GROUP BY value
   ...> ORDER BY cnt DESC
   ...> LIMIT 10;

# %% [markdown]
#     swimming_pool    147
#     playground       121
#     park              63
#     picnic_table      39
#     sports_centre     30
#     pitch             28
#     fitness_centre    16
#     slipway            8
#     dance              6
#     dog_park           3

# %% [markdown]
# ### Top 10 Religions

# %%
sqlite> SELECT value, count(*) as cnt FROM nodes_tags
   ...> WHERE key == 'religion'
   ...> GROUP BY value
   ...> ORDER BY cnt DESC
   ...> LIMIT 10;

# %% [markdown]
#     christian       187
#     buddhist          3
#     jewish            3
#     hindu             2
#     caodaism          1
#     muslim            1
#     rosicrucian       1
#     scientologist     1
#     shinto            1
#     sikh              1

# %% [markdown]
# ### City names

# %%
sqlite> SELECT DISTINCT value FROM nodes_tags
   ...> where key == 'city' and type == 'addr';

# %% [markdown]
#     'Sunnyvale'
#     'Santa Clara'
#     'San Jose'
#     'Morgan Hill'
#     'Campbell'
#     'Los Gatos'
#     'Saratoga'
#     'Cupertino'
#     'Mount Hamilton'
#     'Milpitas'
#     'Felton'
#     'Coyote'
#     'Fremont'

# %% [markdown]
# ### Number of Railway Stations

# %%
sqlite> SELECT count(*) FROM nodes_tags
   ...> WHERE key == 'railway' and value == 'station';

# %% [markdown]
# 9

# %% [markdown]
# ### Number of Theatres

# %%
sqlite> SELECT count(*) as cnt FROM nodes_tags
   ...> WHERE key == 'amenity' and value == 'theatre';

# %% [markdown]
# 7

# %% [markdown]
# ###  Addtional Suggestions
#
# It would be great to include local farmer's markets and ice skating information.
#
# To improve the quality of the data, I suggest that there should a standard format that the users can enter the data or the system should reject. We can use machine learning to learn the existing data and check on new data being entered and flag for errors.

# %% [markdown]
# ### Conclusion
#
# The OpenStreetMap of San Jose, California is of reasonably good quality that has an immense depth of information but has some minor typos and different formats of the same data (example: phone numbers entered are of very different formats, city name with and without accent etc.). This is inevitable since there are so many contributing users. An easy fix may be to use a script to check the format or flag error message when incorrect format is entered by the user.

# %% [markdown]
# ### References
#
# * San Jose Map image from https://mapzen.com/data/metro-extracts/metro/san-jose_california/
#
# * Stack overflow for various python questions http://stackoverflow.com/
#
# * Reg expressions regexone.com/references/python
#
# * Stack overflow for SQL questions
